# %% [markdown]
# # COMP6234

# %% [markdown]
# stpe1: clean data
# for chart 3

# %%
import pandas as pd
import re

# %%
dice_data = pd.read_csv('DICE.csv',usecols=[10])
dice_data
# Out:
#                                                   skills
# 0                                              SEE BELOW
# 1      linux/unix, network monitoring, incident respo...
# 2      Enterprise Solutions Architecture, business in...
# 3                             Please see job description
# 4      Configuration Management, Developer, Linux, Ma...
# 5                   FICO, AR, AP, Asset Management, HAHA
# 6      Cisco, DNS, HTTP, Networking, Network Engineer...
# 7      .NET , C#, MVC, RESTful web services, HTTP, AW...
# 8      C++, Developer, Development, JavaScript, User ...
# 9                                  (See Job Description)
# 10                                             Openstack
# 11     Unix, IAM, Scripting knowledge, OIM, Windows, ...
# 12                                             Java, OSS
# 13            Consulting, Project, Sales, Sales Engineer
# 14                                         mobile device
# ...

# %%
s1 = dice_data.dropna(how='any')['skills']
skill = s1.str.split(',',expand=True)
skill
# Out:
#                                                       0   \
# 0                                              SEE BELOW
# 1                                             linux/unix
# 2                      Enterprise Solutions Architecture
# 3                             Please see job description
# 4                               Configuration Management
# 5                                                   FICO
# 6                                                  Cisco
# 7                                                  .NET
# 8                                                    C++
# 9                                  (See Job Description)
# 10                                             Openstack
# 11                                                  Unix
# 12                                                  Java
# 13                                            Consulting
# 14                                         mobile device
# ...

# %%
skilled = []
for n in range(0,21956):
    for i in range(0,10):
        kk = skill.iloc[n,i]
        if kk != 'None':
            result=kk
            skilled.append(result)
        else:
            result='NaN'
            skilled.append(result)
output = pd.DataFrame({'skill': skilled})
output
# Out:
#                                     skill
# 0                               SEE BELOW
# 1                                    None
# 2                                    None
# 3                                    None
# 4                                    None
# 5                                    None
# 6                                    None
# 7                                    None
# 8                                    None
# 9                                    None
# 10                             linux/unix
# 11                     network monitoring
# 12                      incident response
# 13                 systems administration
# 14                    security accessment
# 15                                   None
# 16                                   None
# 17                                   None
# 18                                   None
# 19                                   None
# 20      Enterprise Solutions Architecture
# ...

# %%
output.to_csv('skill3.csv')

# %% [markdown]
# re-read to clear None

# %%
skilled = pd.read_excel('skill33.xlsx')
skilled
# Out:
#                                    skill
# 0                              SEE BELOW
# 1                             linux/unix
# 2                     network monitoring
# 3                      incident response
# 4                 systems administration
# 5                    security accessment
# 6      Enterprise Solutions Architecture
# 7                   business inteligence
# 8                                reports
# 9                              reporting
# 10            Please see job description
# 11              Configuration Management
# 12                             Developer
# 13                                 Linux
# 14                            Management
# 15                   Process Engineering
# 16                                VMware
# 17                                  FICO
# 18                                    AR
# 19                                    AP
# 20                      Asset Management
# 21                                  HAHA
# ...

# %%
skilled.to_csv('skill_output.csv')
